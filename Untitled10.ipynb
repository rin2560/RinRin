# %% [markdown]
# <a href="https://colab.research.google.com/github/rin2560/RinRin/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ceb017ca-0cb3-40d2-9e1e-854e408aad34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ceb017ca-0cb3-40d2-9e1e-854e408aad34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import shutil

original_path = "06.【様式】出張・研修旅行願(総務・企画係提出）【R7.04更新版】のコピー.docx"
safe_path = "shuccho_template.docx"

shutil.copyfile(original_path, safe_path)

# Wordファイル読み込み
doc = Document(safe_path)

# テキスト置換関数（段落・テーブル両方対応）
def replace_all_text(doc, replacements):
    def replace_in_para(para):
        for old, new in replacements.items():
            if old in para.text:
                for run in para.runs:
                    run.text = run.text.replace(old, new)
    def replace_in_tables():
        for table in doc.tables:
            for row in table.rows:
                for cell in row.cells:
                    for para in cell.paragraphs:
                        replace_in_para(para)
    for para in doc.paragraphs:
        replace_in_para(para)
    replace_in_tables()

# 置換内容（自由に編集可）
replacements = {
    "職　　名": "職　　名：データサイエンス・AIイノベーション研究推進センター　助教",
    "氏    名": "氏    名：千代延　未帆",
    "令和   年   月   日～令和   年   月   日（    日間）": "令和7年9月1日～令和7年9月4日（4日間）",
    "（住　所）": "（住　所）162-8601 東京都新宿区神楽坂1-3",
    "機 関 名\n(施 設 名)": "機 関 名\n(施 設 名)：東京理科大学（神楽坂キャンパス）",
    "用  務  内  容": "用  務  内  容：日本応用数理学会年会への出席",
    "□日帰り旅行": "□日帰り旅行",
    "□宿泊旅行": "☑宿泊旅行",  # 必要なら ☑ に
    "□有（宿泊地：　　　市・区）": "☑有（宿泊地：東京都千代田区）",
    "□無": "☐無",
    "□個人研究費": "☑個人研究費",
    "□科学研究費補助金": "□科学研究費補助金",
    "□私　費 (研修旅行)": "☐私　費 (研修旅行)",
    "概算払（事前支払い）": "☑概算払（事前支払い）",
    "精算払（事後精算払い）": "☐精算払（事後精算払い）",
}

# 置換実行
replace_all_text(doc, replacements)

# 保存
output_path = "/content/出張願_編集済.docx"
doc.save(output_path)
